# %% [markdown]
# ### DemTools01:

# %% [markdown]
# # CP functions

# %%
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import cm
# %matplotlib notebook

# %% [markdown]
# * Data and function for plotting

# %%
def plotcontour(f, n=201, a=2):
    k = np.linspace(-a, a, n)
    x, y = np.meshgrid(k, k)
    z = f(x, y)
    
    fig = plt.figure()
    CS = plt.contour(x, y, z)
    plt.clabel(CS, inline=1, fontsize=10)

# %% [markdown]
# ## Fischer function
# $$\phi_F(u, v) = \sqrt{u^2 + v^2} -u - v$$

# %%
def Fischer(u, v): 
    return np.sqrt(u**2 +v**2) - u - v

plotcontour(Fischer)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Minimum
# $$\phi_{NR}(u,v) = \min(u, v)$$

# %%
plotcontour(np.minimum)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Mangasarian and Solodov function
# $$\phi_{Reg}(u,v) = uv + \frac{1}{2\alpha}[\max(0, u-\alpha v)^2 - u^2] $$

# %%
def msf(u, v, alpha=1):
    return u*v + (np.maximum(0, u - alpha*v)**2 - u**2)/(2*alpha)

plotcontour(msf)
# Out:
# <img src="data:image/png;base64,...">
